# %% [markdown]
# # Ejemplo de como usar qagraphutils para evaluar distintas respuestas

# %%
import sys
sys.path.append('../lib')

import qagraphutils as qagr

# %%
filename_to_eval = "People_Argentina_2years_v0_2_expert_vs_simple.json"
qagr.show_evaluate_responses_as_bar_graph(filename_to_eval=filename_to_eval)

# %%
filename_to_eval = "People_Argentina_2years_v0_2_expert_vs_complex.json"
qagr.show_evaluate_responses_as_bar_graph(filename_to_eval=filename_to_eval)

# %%
filename_to_eval = "People_Argentina_2years_v0_2_simple_vs_complex.json"
qagr.show_evaluate_responses_as_bar_graph(filename_to_eval=filename_to_eval)
